# %% [markdown]
# #Questão 01
#
# Os dados a seguir sobre precipitação (acre-pé) de 26 nuvens esparsas foram obtidos do artigo A Bayesian Analysis of a Multiplicative Treatment Effect in Weather Modification (Technometrics, 1975, p. 161-166).

# %% [markdown]
# ![Captura de tela de 2023-09-10 17-52-00.png](data:image/png;base64,...)

# %% [markdown]
# ###Desenvolva um código python que calcule a média, mediana, desvio-padrão e faça o plote do diagrama de caixa.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = [4.1, 115.3, 7.7, 118.3, 255.0, 703.4, 274.7, 978.0, 17.5, 119.0, 274.7, 1656.0, 31.4, 302.8, 1697.8, 129.6, 32.7, 198.6, 334.1, 2745.6, 40.6, 200.7, 430.0, 242.5, 489.1, 92.4]

# %%
print(np.average(dados))
# Out:
# 441.9846153846153

# %%
print(np.median(dados))
# Out:
# 221.6

# %%
print(np.std(dados))
# Out:
# 638.1493240326387

# %%
plt.boxplot(dados, vert=0)
plt.title("Distribuição dos valores")
# Out:
# Text(0.5, 1.0, 'Distribuição dos valores')
